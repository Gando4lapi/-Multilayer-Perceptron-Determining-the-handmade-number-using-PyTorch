# %%
# %pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\egorc\miniconda3\lib\site-packages (2.8.0)
# Requirement already satisfied: filelock in c:\users\egorc\miniconda3\lib\site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\egorc\appdata\roaming\python\python313\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\egorc\appdata\roaming\python\python313\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\egorc\miniconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\egorc\miniconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\egorc\miniconda3\lib\site-packages (from torch) (2025.9.0)
# Requirement already satisfied: setuptools in c:\users\egorc\miniconda3\lib\site-packages (from torch) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\egorc\appdata\roaming\python\python313\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\egorc\miniconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# %pip install tqdm
# %pip install numpy
# %pip install scipy
# %pip install scikit-learn
# %pip install torchvision
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.6-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.59.2-cp313-cp313-win_amd64.whl.metadata (111 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Collecting numpy>=1.23 (from matplotlib)
#   Using cached numpy-2.3.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\egorc\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\egorc\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\egorc\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.6-cp313-cp313-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.59.2-cp313-cp313-win_amd64.whl (2.3 MB)
# Using cached kiwisolver-1.4.9-cp313-cp313-win_amd64.whl (73 kB)
# Downloading numpy-2.3.2-cp313-cp313-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.8 MB 9.5 MB/s eta 0:00:02
#    --------- ------------------------------ 3.1/12.8 MB 10.8 MB/s eta 0:00:01
#    ------------- -------------------------- 4.2/12.8 MB 10.7 MB/s eta 0:00:01
#    --------------------------- ------------ 8.9/12.8 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 9.0 MB/s eta 0:00:00
# Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ------------------------ --------------- 4.2/7.0 MB 20.3 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 16.9 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    --------------- ------------------------ 3/8 [kiwisolver]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ---------------------------------------- 8/8 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.59.2 kiwisolver-1.4.9 matplotlib-3.10.6 numpy-2.3.2 pillow-11.3.0 pyparsing-3.2.3
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in c:\users\egorc\miniconda3\lib\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\egorc\appdata\roaming\python\python313\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\egorc\miniconda3\lib\site-packages (2.3.2)
# Note: you may need to restart the kernel to use updated packages.
# Collecting scipy
#   Using cached scipy-1.16.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\egorc\miniconda3\lib\site-packages (from scipy) (2.3.2)
# Downloading scipy-1.16.1-cp313-cp313-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#     --------------------------------------- 0.8/38.5 MB 5.6 MB/s eta 0:00:07
#    -- ------------------------------------- 2.6/38.5 MB 7.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.7/38.5 MB 8.8 MB/s eta 0:00:04
#    ------- -------------------------------- 6.8/38.5 MB 9.0 MB/s eta 0:00:04
#    --------- ------------------------------ 9.4/38.5 MB 9.8 MB/s eta 0:00:03
#    ------------ --------------------------- 12.1/38.5 MB 10.3 MB/s eta 0:00:03
#    -------------- ------------------------- 14.4/38.5 MB 10.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 16.3/38.5 MB 10.3 MB/s eta 0:00:03
#    ------------------- -------------------- 18.6/38.5 MB 10.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.8/38.5 MB 11.0 MB/s eta 0:00:02
#    ------------------------- -------------- 24.6/38.5 MB 11.2 MB/s eta 0:00:02
#    --------------------------- ------------ 26.5/38.5 MB 11.0 MB/s eta 0:00:02
#    ------------------------------ --------- 29.4/38.5 MB 11.3 MB/s eta 0:00:01
#    --------------------------------- ------ 32.2/38.5 MB 11.4 MB/s eta 0:00:01
#    ------------------------------------ --- 35.4/38.5 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 4.3 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.16.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\egorc\miniconda3\lib\site-packages (from scikit-learn) (2.3.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\egorc\miniconda3\lib\site-packages (from scikit-learn) (1.16.1)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.7.1-cp313-cp313-win_amd64.whl (8.7 MB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
#
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    ---------------------------------------- 3/3 [scikit-learn]
#
# Successfully installed joblib-1.5.2 scikit-learn-1.7.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting torchvision
#   Using cached torchvision-0.23.0-cp313-cp313-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy in c:\users\egorc\miniconda3\lib\site-packages (from torchvision) (2.3.2)
# Requirement already satisfied: torch==2.8.0 in c:\users\egorc\miniconda3\lib\site-packages (from torchvision) (2.8.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\egorc\miniconda3\lib\site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: filelock in c:\users\egorc\appdata\roaming\python\python313\site-packages (from torch==2.8.0->torchvision) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\egorc\appdata\roaming\python\python313\site-packages (from torch==2.8.0->torchvision) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\egorc\appdata\roaming\python\python313\site-packages (from torch==2.8.0->torchvision) (1.14.0)
# Requirement already satisfied: networkx in c:\users\egorc\appdata\roaming\python\python313\site-packages (from torch==2.8.0->torchvision) (3.5)
# Requirement already satisfied: jinja2 in c:\users\egorc\appdata\roaming\python\python313\site-packages (from torch==2.8.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\egorc\appdata\roaming\python\python313\site-packages (from torch==2.8.0->torchvision) (2025.9.0)
# Requirement already satisfied: setuptools in c:\users\egorc\appdata\roaming\python\python313\site-packages (from torch==2.8.0->torchvision) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\egorc\appdata\roaming\python\python313\site-packages (from sympy>=1.13.3->torch==2.8.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\egorc\appdata\roaming\python\python313\site-packages (from jinja2->torch==2.8.0->torchvision) (3.0.2)
# Using cached torchvision-0.23.0-cp313-cp313-win_amd64.whl (1.6 MB)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %%
class MNIST_Multilayer_Perceptron(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(784, 256), nn.ReLU(),
            nn.Linear(256, 128), nn.ReLU(),
            nn.Linear(128, 10)
        )
    def forward(self, x):
        return self.net(x)

# %%
mnist_train = datasets.MNIST(root="./datasets", train=True, transform=transforms.ToTensor(), download=True)
mnist_test = datasets.MNIST(root="./datasets", train=False, transform=transforms.ToTensor(), download=True)

# %%
train_loader = torch.utils.data.DataLoader(mnist_train, batch_size=100, shuffle=True)
test_loader = torch.utils.data.DataLoader(mnist_test, batch_size=100, shuffle=False)

# %%
model = MNIST_Multilayer_Perceptron()

# %%
criterion = nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %%
from tqdm import tqdm

# %%
model.train()
for images, labels in tqdm(train_loader):
    optimizer.zero_grad()
    x = images.view(-1, 28*28)
    y = model(x)
    loss = criterion(y, labels)
    loss.backward()
    optimizer.step()
# Out:
#   0%|                                                                        | 0/600 [00:00<?, ?it/s]
#   2%|▉                                                               | 9/600 [00:00<00:07, 80.48it/s]
#   3%|█▉                                                             | 19/600 [00:00<00:06, 89.38it/s]
#   5%|███                                                            | 29/600 [00:00<00:06, 90.02it/s]
#   6%|████                                                           | 39/600 [00:00<00:06, 86.66it/s]
#   8%|█████▏                                                         | 49/600 [00:00<00:06, 88.14it/s]
#  10%|██████                                                         | 58/600 [00:00<00:06, 88.44it/s]
#  69%|██████████████████████████████████████████▉                   | 416/600 [00:04<00:02, 89.72it/s]
#  71%|████████████████████████████████████████████                  | 426/600 [00:04<00:01, 90.87it/s]
#  73%|█████████████████████████████████████████████                 | 436/600 [00:04<00:01, 92.42it/s]
#  74%|██████████████████████████████████████████████                | 446/600 [00:04<00:01, 93.82it/s]
#  76%|███████████████████████████████████████████████               | 456/600 [00:04<00:01, 91.21it/s]
#  78%|████████████████████████████████████████████████▏             | 466/600 [00:05<00:01, 90.12it/s]
#  79%|█████████████████████████████████████████████████▏            | 476/600 [00:05<00:01, 91.22it/s]
#  81%|██████████████████████████████████████████████████▏           | 486/600 [00:05<00:01, 90.33it/s]
#  83%|███████████████████████████████████████████████████▎          | 496/600 [00:05<00:01, 92.42it/s]
#  84%|████████████████████████████████████████████████████▎         | 506/600 [00:05<00:01, 91.11it/s]
#  86%|█████████████████████████████████████████████████████▎        | 516/600 [00:05<00:00, 85.51it/s]
#  88%|██████████████████████████████████████████████████████▎       | 525/600 [00:05<00:00, 85.83it/s]
#  89%|███████████████████████████████████████████████████████▎      | 535/600 [00:05<00:00, 88.16it/s]
#  91%|████████████████████████████████████████████████████████▎     | 545/600 [00:05<00:00, 90.12it/s]
#  92%|█████████████████████████████████████████████████████████▎    | 555/600 [00:06<00:00, 92.10it/s]
#  94%|██████████████████████████████████████████████████████████▍   | 565/600 [00:06<00:00, 92.91it/s]
#  96%|███████████████████████████████████████████████████████████▍  | 575/600 [00:06<00:00, 94.09it/s]
#  98%|████████████████████████████████████████████████████████████▍ | 585/600 [00:06<00:00, 91.51it/s]
# 100%|██████████████████████████████████████████████████████████████| 600/600 [00:06<00:00, 90.96it/s]

# %%
model.eval()
correct = 0
total = len(mnist_test)
with torch.no_grad():
    for images, labels in tqdm(test_loader):
        x = images.view(-1, 28*28)
        y = model(x)
        preds = torch.argmax(y, dim=1)
        correct += (preds == labels).sum().item()

print("test accuracy:", correct/total)
# Out:
#   0%|                                                                        | 0/100 [00:00<?, ?it/s]
#   9%|█████▊                                                          | 9/100 [00:00<00:01, 86.85it/s]
#  19%|███████████▉                                                   | 19/100 [00:00<00:00, 94.02it/s]
#  29%|██████████████████▎                                            | 29/100 [00:00<00:00, 92.93it/s]
#  39%|████████████████████████▌                                      | 39/100 [00:00<00:00, 90.61it/s]
#  50%|███████████████████████████████▌                               | 50/100 [00:00<00:00, 93.61it/s]
#  60%|█████████████████████████████████████▊                         | 60/100 [00:00<00:00, 94.89it/s]
#  70%|████████████████████████████████████████████                   | 70/100 [00:00<00:00, 92.30it/s]
#  80%|██████████████████████████████████████████████████▍            | 80/100 [00:00<00:00, 91.48it/s]
# 100%|██████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 92.86it/s]
# test accuracy: 0.9156
